# %%
TEAMS = ['Flamengo', 'Ceara', 'Sport', 'Bahia', 'Palmeiras', 'Inter', 'Santos', 'Grêmio', 'Fortaleza', 'Atlético Mineiro',
        'Bragantino', 'Chapecoense', 'Botafogo', 'Vasco', 'São Paulo', 'Corinthians']
print("Welcome to the COPA DO BRASIL championship\n")
print("We have 16 teams. Let's discover which of them is going to win!\n")
print("Pick up a team and have a good luck!\n")
ANSWER = input("Do you wanna play? Type 'Yes' or 'No'.\n")

# PARTE 1: Feita para adequar qualquer tipo de resposta Yes ou No ao usuário, por exemplo, se ele digitar "YES, yes, yeS, YEs
#... ou NO, No, no, nO, todas essas possibilidades serão aceitas. Se ele digitar que não quer jogar, será levantado um erro
# se ele digitar qualquer coisa diferente disso, será requerido para digitar Yes ou No.

y = ANSWER.capitalize()
if y == 'Yes': 
    print('That is AWESOME! Lets do it.\n')
elif y == 'No': 
    print("Ok... thank you by the way!\n")
    raise     
elif y != 'Yes' or y != 'No':
    while y != 'Yes' or y != 'No':
        print("Type Yes or No please\n")
        Z = input("Do you wanna play? Type 'Yes' or 'No'.\n")
        W = Z.capitalize()
        if W == 'Yes' or W == 'No':
            if W == 'Yes': 
                print('That is AWESOME! Lets do it.\n')
                break
            elif W == 'No': 
                print("Ok... thank you by the way!\n")
                raise     
                
# PARTE 2: Aqui tem o mesmo sentido da parte 1. Caso o usuário digite o nome dos times de diferentes formas, ainda sim será
# aceita aquela resposta que possui todos os caracteres do time escolhido na lista de times.

print("Which team do you wish to win?")
X = input()
word = X.capitalize()

if word in TEAMS:
    print("Ok! You selected:", word)      
else:
    while word not in TEAMS:
        print("We do not have this team. Try again\n")
        trying = input('Which team do you wish to win the championship?\n')
        word2 = trying.capitalize()
        if word2 in TEAMS:
            print("Ok! You selected:", word2, '\n')
            break      
# PARTE 3: Classe

class Team:
    
    """A classe Team tem o intuito de apresentar os pontos de cada time de acordo com o ranking da CBF de 2021, bem como os
    principais jogadores desses clubes. Além disso, a classe possuia a função CHANCE que calcula a porcentagem de chance de 
    vitória para cada equipe de acordo com os pontos mencionados. Vale ressaltar, ainda, que eu calculei a probabilidade
    tomando 20 pontos como 100%"""
    
    def __init__(self, team, pontos_cbf, jogador):
        self.team = team
        self.pontos_cbf = pontos_cbf
        self.jogador = jogador 
        
    def chance(self):
        chance_porc = (self.pontos_cbf / 20) * 100
        print("A chance do", self.team, "ser campeão é:", chance_porc, "%") 
        
# Aqui foi a utilização da classe e suas respectivas funções 

print("According to the CBF ranking:\n")
FLA = Team('Flamengo', 16.7, 'Gabigol')
CEA = Team('Ceará', 9.2, 'Vina')
PAL = Team('Palmeiras', 16.1, 'Felipe Melo')        
BAH = Team('Bahia', 10.2, 'Rodriguinho')        
SPO = Team('Sport', 7, 'Thiago Neves')
INT = Team('Internacional', 13.3, 'Galhardo')
GRE = Team('Grêmio', 15.2, 'Diego Souza')
SAN = Team('Santos', 12.8, 'Marinho')
FOR = Team('Fortaleza', 8, 'Osvaldo')
CHA = Team('Chapecoense', 9, 'Anselmo Ramon')
BRA = Team('Bragantino', 6.3, 'Claudinho')
BOT = Team('Botafogo', 9.5, 'Gatito')
VAS = Team('Vasco', 9, 'Talles Magno')
COR = Team('Corinthians', 12, 'Cássio')
SAO = Team('São Paulo', 12, 'Daniel Alves')
ATE = Team('Atlético Mineiro', 12, 'Hulk')

FLA.chance()
print("Special player:", FLA.jogador, '\n')
CEA.chance()
print("Special player:", CEA.jogador, '\n')
PAL.chance()
print("Special player:", PAL.jogador, '\n')
BAH.chance()
print("Special player:", BAH.jogador, '\n')
SPO.chance()
print("Special player:", SPO.jogador, '\n')
INT.chance()
print("Special player:", INT.jogador, '\n')
GRE.chance()
print("Special player:", GRE.jogador, '\n')
SAN.chance()
print("Special player:", SAN.jogador, '\n')
FOR.chance()
print("Special player:", FOR.jogador, '\n')
CHA.chance()
print("Special player:", CHA.jogador, '\n')
BRA.chance()
print("Special player:", BRA.jogador, '\n')
BOT.chance()
print("Special player:", BOT.jogador, '\n')
VAS.chance()
print("Special player:", VAS.jogador, '\n')
COR.chance()
print("Special player:", COR.jogador, '\n')
SAO.chance()
print("Special player:", SAO.jogador, '\n')
ATE.chance()
print("Special player:", ATE.jogador, '\n')


print("OK! We are ready to start the championship!") 
print("Lets see if", word, "is going to win!!!\n")

# PARTE 4: Utilização de funções

TEAMS = ['Flamengo', 'Ceara', 'Sport', 'Bahia', 'Palmeiras', 'Inter', 'Santos', 'Grêmio', 'Fortaleza', 'Atlético Mineiro',
        'Bragantino', 'Chapecoense', 'Botafogo', 'Vasco', 'São Paulo', 'Corinthians']
WINNERS = []
WINNERS_16 = []
WINNERS_SEMI = []
def roundof16_1(y):
    
    """Essa função tira dois times da lista TEAMS de forma aleatória para realizar o primeiro confronto das oitavas de final
    e escolhe o vencedor com sorteio realizado pelo computador. Depois, adiciona o vencedor na lista WINNERS para realizar
    as quartas de final"""
    
    import random 
    x = random.sample(y, 2)
    for i in x:
        print("The first match is goint to be:", x[0], "x", x[1])
        y.remove(x[0])
        y.remove(x[1])
        q = random.choice(x)
        input()
        print("The first winner is:", q, "\n")
        global WINNERS
        WINNERS.append(q)
        break 
        
def roundof16_2(y):
    
    """Essa função tira dois times da lista TEAMS de forma aleatória para realizar o segundo confronto das oitavas de final
    e escolhe o vencedor com sorteio realizado pelo computador. Depois, adiciona o vencedor na lista WINNERS para realizar
    as quartas de final"""
    import random 
    x = random.sample(y, 2)
    for i in x:
        print("The second match is goint to be:", x[0], "x", x[1])
        y.remove(x[0])
        y.remove(x[1])
        q = random.choice(x)
        input()
        print("The second winner is:", q, "\n")
        global WINNERS
        WINNERS.append(q)
        break          

def roundof16_3(y):
    
    
    """Essa função tira dois times da lista TEAMS de forma aleatória para realizar o terceiro confronto das oitavas de final
    e escolhe o vencedor com sorteio realizado pelo computador. Depois, adiciona o vencedor na lista WINNERS para realizar
    as quartas de final"""
    import random 
    x = random.sample(y, 2)
    for i in x:
        print("The third match is goint to be:", x[0], "x", x[1])
        y.remove(x[0])
        y.remove(x[1])
        q = random.choice(x)
        input()
        print("The third winner is:", q, "\n")
        global WINNERS
        WINNERS.append(q)
        break  
        
def roundof16_4(y):
    
    """Essa função tira dois times da lista TEAMS de forma aleatória para realizar o quarto confronto das oitavas de final
    e escolhe o vencedor com sorteio realizado pelo computador. Depois, adiciona o vencedor na lista WINNERS para realizar
    as quartas de final"""
    import random 
    x = random.sample(y, 2)
    for i in x:
        print("The fourth match is goint to be:", x[0], "x", x[1])
        y.remove(x[0])
        y.remove(x[1])
        q = random.choice(x)
        input()
        print("The fourth winner is:", q, "\n")
        global WINNERS
        WINNERS.append(q)
        break  

def roundof16_5(y):
    
    
    """Essa função tira dois times da lista TEAMS de forma aleatória para realizar o quinto confronto das oitavas de final
    e escolhe o vencedor com sorteio realizado pelo computador. Depois, adiciona o vencedor na lista WINNERS para realizar
    as quartas de final"""
    import random 
    x = random.sample(y, 2)
    for i in x:
        print("The fifth match is goint to be:", x[0], "x", x[1])
        y.remove(x[0])
        y.remove(x[1])
        q = random.choice(x)
        input()
        print("The fifth winner is:", q, "\n")
        global WINNERS
        WINNERS.append(q)
        break  

def roundof16_6(y):
    
    
    """Essa função tira dois times da lista TEAMS de forma aleatória para realizar o sexto confronto das oitavas de final
    e escolhe o vencedor com sorteio realizado pelo computador. Depois, adiciona o vencedor na lista WINNERS para realizar
    as quartas de final"""
    import random 
    x = random.sample(y, 2)
    for i in x:
        print("The sixth match is goint to be:", x[0], "x", x[1])
        y.remove(x[0])
        y.remove(x[1])
        q = random.choice(x)
        input()
        print("The sixth winner is:", q, "\n")
        global WINNERS
        WINNERS.append(q)
        break  

def roundof16_7(y):
    
    """Essa função tira dois times da lista TEAMS de forma aleatória para realizar o sétimo confronto das oitavas de final
    e escolhe o vencedor com sorteio realizado pelo computador. Depois, adiciona o vencedor na lista WINNERS para realizar
    as quartas de final"""
    
    import random 
    x = random.sample(y, 2)
    for i in x:
        print("The seventh match is goint to be:", x[0], "x", x[1])
        y.remove(x[0])
        y.remove(x[1])
        q = random.choice(x)
        input()
        print("The seventh winner is:", q, "\n")
        global WINNERS
        WINNERS.append(q)
        break  
        
def roundof16_8(y):
    
    """Essa função tira dois times da lista TEAMS de forma aleatória para realizar o oitavo confronto das oitavas de final
    e escolhe o vencedor com sorteio realizado pelo computador. Depois, adiciona o vencedor na lista WINNERS para realizar
    as quartas de final"""
    
    import random 
    x = random.sample(y, 2)
    for i in x:
        print("The eighth match is goint to be:", x[0], "x", x[1])
        y.remove(x[0])
        y.remove(x[1])
        q = random.choice(x)
        input()
        print("The eighth winner is:", q, "\n")
        global WINNERS
        WINNERS.append(q)
        break  
        
def quarterfinals(y):
    
    
    
    """Essa função tira dois times da lista WINNERS de forma aleatória para realizar o primeiro confronto das quartas de final
    e escolhe o vencedor com sorteio realizado pelo computador. Depois, adiciona o vencedor na lista WINNERS_16 para realizar
    as semi-finais"""
    
        
    import random 
    x = random.sample(y, 2)
    for i in x:
        print("The ninth match is goint to be:", x[0], "x", x[1])
        y.remove(x[0])
        y.remove(x[1])
        q = random.choice(x)
        input()
        print("The ninth winner is:", q, "\n")
        global WINNERS_16
        WINNERS_16.append(q)
        break    
        
def quarterfinals2(y):
    
    """Essa função tira dois times da lista WINNERS de forma aleatória para realizar o segundo confronto das quartas de final
    e escolhe o vencedor com sorteio realizado pelo computador. Depois, adiciona o vencedor na lista WINNERS_16 para realizar
    as semi-finais"""
    
    import random 
    x = random.sample(y, 2)
    for i in x:
        print("The tenth match is goint to be:", x[0], "x", x[1])
        y.remove(x[0])
        y.remove(x[1])
        q = random.choice(x)
        input()
        print("The tenth winner is:", q, "\n")
        global WINNERS_16
        WINNERS_16.append(q)
        break    
        
def quarterfinals3(y):
    
    """Essa função tira dois times da lista WINNERS de forma aleatória para realizar o terceiro confronto das quartas de final
    e escolhe o vencedor com sorteio realizado pelo computador. Depois, adiciona o vencedor na lista WINNERS_16 para realizar
    as semi-finais"""
    
    
    import random 
    x = random.sample(y, 2)
    for i in x:
        print("The eleventh match is goint to be:", x[0], "x", x[1])
        y.remove(x[0])
        y.remove(x[1])
        q = random.choice(x)
        input()
        print("The eleventh winner is:", q, "\n")
        global WINNERS_16
        WINNERS_16.append(q)
        break        
        
def quarterfinals4(y):
    
    """Essa função tira dois times da lista WINNERS de forma aleatória para realizar o quarto confronto das quartas de final
    e escolhe o vencedor com sorteio realizado pelo computador. Depois, adiciona o vencedor na lista WINNERS_16 para realizar
    as semi-finais"""
    
    
    import random 
    x = random.sample(y, 2)
    for i in x:
        print("The twelfth match is goint to be:", x[0], "x", x[1])
        y.remove(x[0])
        y.remove(x[1])
        q = random.choice(x)
        input()
        print("The twelfth winner is:", q, "\n")
        global WINNERS_16
        WINNERS_16.append(q)
        break     

def semifinals(y):
    
    
    """Essa função tira dois times da lista WINNERS_16 de forma aleatória para realizar o primeiro confronto das semi-finais
    e escolhe o vencedor com sorteio realizado pelo computador. Depois, adiciona o vencedor na lista WINNERS_SEMI para
    realizar a final"""
    
    
    import random 
    x = random.sample(y, 2)
    for i in x:
        print("The thirteenth match is goint to be:", x[0], "x", x[1])
        y.remove(x[0])
        y.remove(x[1])
        q = random.choice(x)
        input()
        print("The thirteenth winner is:", q, "\n")
        global WINNERS_SEMI
        WINNERS_SEMI.append(q)
        break     

def semifinals2(y):
    
    """Essa função tira dois times da lista WINNERS_16 de forma aleatória para realizar o segundo confronto das semi-finais
    e escolhe o vencedor com sorteio realizado pelo computador. Depois, adiciona o vencedor na lista WINNERS_SEMI para
    realizar a final"""
    
    import random 
    x = random.sample(y, 2)
    for i in x:
        print("The fourteenth match is goint to be:", x[0], "x", x[1])
        y.remove(x[0])
        y.remove(x[1])
        q = random.choice(x)
        input()
        print("The fourteenth winner is:", q, "\n")
        global WINNERS_SEMI
        WINNERS_SEMI.append(q)
        break  

def final(y):
    
    """Essa função tira dois times da lista WINNERS_SEMI de forma aleatória para realizar o confronto da final e escolhe
    o vencedor do campeonato com sorteio realizado pelo computador. Por fim,  a função avisa se você venceu ou não."""
    
    import random 
    x = random.sample(y, 2)
    for i in x:
        print("The fifteenth and LAST match is goint to be:", x[0], "x", x[1])
        y.remove(x[0])
        y.remove(x[1])
        q = random.choice(x)
        input()
        print("THE CHAMPION IS :", q, "!!!!!!!!!!!\n")
        global word
        if word == q:
            print('You WON !!!!')
        else:
            print('Maybe next time...')
        break
        
#PARTE 5: Realização do código 
input("Press enter to keep going!\n") 
roundof16_1(TEAMS)
roundof16_2(TEAMS)   
roundof16_3(TEAMS)
roundof16_4(TEAMS)
roundof16_5(TEAMS) 
roundof16_6(TEAMS)
roundof16_7(TEAMS) 
roundof16_8(TEAMS) 
print("QUARTER-FINALS--------------------\n")
quarterfinals(WINNERS) 
quarterfinals2(WINNERS)
quarterfinals3(WINNERS)
quarterfinals4(WINNERS)
print("SEMI-FINALS--------------------\n")
semifinals(WINNERS_16)
semifinals2(WINNERS_16)
print("FINAL NOW!!!--------------------\n")
final(WINNERS_SEMI)
# Out:
# Welcome to the COPA DO BRASIL championship
#
# We have 16 teams. Let's discover which of them is going to win!
#
# Pick up a team and have a good luck!
#
# Do you wanna play? Type 'Yes' or 'No'.
# yes
# That is AWESOME! Lets do it.
#
# Which team do you wish to win?
# ceara
# Ok! You selected: Ceara
# According to the CBF ranking:
#
# A chance do Flamengo ser campeão é: 83.5 %
# Special player: Gabigol
#
# A chance do Ceará ser campeão é: 46.0 %
# Special player: Vina
#
# A chance do Palmeiras ser campeão é: 80.5 %
# Special player: Felipe Melo
#
# A chance do Bahia ser campeão é: 51.0 %
# Special player: Rodriguinho
#
# A chance do Sport ser campeão é: 35.0 %
# Special player: Thiago Neves
#
# A chance do Internacional ser campeão é: 66.5 %
# Special player: Galhardo
#
# A chance do Grêmio ser campeão é: 76.0 %
# Special player: Diego Souza
#
# A chance do Santos ser campeão é: 64.0 %
# Special player: Marinho
#
# A chance do Fortaleza ser campeão é: 40.0 %
# ...
